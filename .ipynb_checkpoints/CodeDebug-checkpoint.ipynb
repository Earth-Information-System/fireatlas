# %% [markdown]
# # FEDS debugging system

# %% [markdown]
# ## Fire_Forward in FireMain.py

# %%
import ycpy
ycpy.util.nowarn()

# %%
import FireObj
import FireIO
import FireConsts
import FireMain

# %%
import importlib
importlib.reload(FireIO)
importlib.reload(FireMain)
importlib.reload(FireObj)
importlib.reload(FireConsts)
# Out:
# <module 'FireConsts' from '/Volumes/GoogleDrive/My Drive/My/My.Research/UCI/ProjectsFull/California.fire/Code/fireatlas/FireConsts.py'>

# %%
import os
import glob

# %%
import pandas as pd
import geopandas as gpd
from datetime import date

# %%
tst=(2020,9,5,'AM')
ted=(2020,11,5,'PM')
region = ('Creek',[-119.5,36.8,-118.9,37.7])

# %%
src = 'SNPP'
nrt = False

# %%
allfires = FireMain.Fobj_init(tst,region[0],restart=False)

# %%
t = list(tst)

# %%
t
# Out:
# [2020, 9, 5, 'AM']

# %%
allfires.number_of_fires,allfires.number_of_validfires
# Out:
# (5, 1)

# %%
allfires.fires[0].fireID,allfires.fires[1].fireID,allfires.fires[2].fireID
# Out:
# (0, 1, 2)

# %%
allfires.fids_expanded,allfires.fids_new,allfires.fids_merged,allfires.fids_invalid
# Out:
# ([0], [3, 4], [0], [3, 4])

# %%
allfires.fires[0].t,len(allfires.fires[0].newpixels),len(allfires.fires[0].pixels)
# Out:
# ([2020, 9, 6, 'AM'], 1972, 2353)

# %%
fids_ne,fids_ea,fids_sleep
# Out:
# ([0, 3, 4], [0, 3, 4], [])

# %%
fids_ea = allfires.fids_active

# %%
allfires.update_t(t)

# %%
allfires.reset_fids_updated()

# %%
allfires.update_t_allfires(t)  # update t
allfires.reset_newpixels()     # reset newpixels

# %%
afp = FireIO.read_AFP(t,src=src,nrt=nrt,region=region)

# %%
allfires = FireMain.Fire_expand_rtree(allfires,afp,fids_ea)

# %%
fids_ne = allfires.fids_ne                         # new or expanded fires id
fids_ea = sorted(set(fids_ea+allfires.fids_new))   # existing active fires (new fires included)
fids_sleep = allfires.fids_sleeper

# %%
allfires = FireMain.Fire_merge_rtree(allfires,fids_ne,fids_ea,fids_sleep)

# %%
allfires.updateftypes()

# %%
allfires.invalidate_statfires()

# %%
allfires.fires[0].pixels[-1].datetime
# Out:
# Timestamp('2020-09-06 09:42:00')

# %%
t = FireObj.t_nb(t,nb='next')

# %%
allfires.fires[0].hull

# %%
allfiresdic = {f.fireID:f for f in allfires.fires}

# %%
allfires.fires
# Out:
# [<FireObj.Fire at 0x7fbc1c68c5d0>,
#  <FireObj.Fire at 0x7fbc1cc09810>,
#  <FireObj.Fire at 0x7fbc1c8657d0>,
#  <FireObj.Fire at 0x7fbc1ccd9bd0>,
#  <FireObj.Fire at 0x7fbc1c95f310>]

# %%
allfiresdic
# Out:
# {0: <FireObj.Fire at 0x7fbc1c68c5d0>,
#  1: <FireObj.Fire at 0x7fbc1cc09810>,
#  2: <FireObj.Fire at 0x7fbc1c8657d0>,
#  3: <FireObj.Fire at 0x7fbc1ccd9bd0>,
#  4: <FireObj.Fire at 0x7fbc1c95f310>}

# %%
fids_ea = allfires.fids_active

# %%
fids_ea
# Out:
# [0]

# %%
eafires = [allfiresdic[fid]  for fid in fids_ea]

# %%
eafires[0].fireID
# Out:
# 0

# %% [markdown]
# ### Functioning at each time step

# %% [markdown]
# Set time and region

# %%
# set time
# t = (2021,8,1,'AM')
t = (2021,8,6,'PM')

from datetime import date
d = date(*t[:-1])

# %%
# set region
# region = ['Brazil',[-55,-25,-45,-15]]

# shp_CA = FireIO.get_Cal_shp()
# region = ['CA',shp_CA]
# regbox = region[1].bounds

region = ('Dixie',[-121.6,39.8,-120.5,40.6])
regbox = region[1]

shp_Reg = FireIO.get_reg_shp(region[1])

# %% [markdown]
# Fobj_init

# %%
allfires = FireMain.Fobj_init(t,restart=True)

# %%
# 2. update allfires and fire object changes due to temporal progression
fids_ea = allfires.fids_active
# all fires
allfires.update_t(t)           # update t for allfires
allfires.reset_fids_updated()  # reset fids_expanded, fids_new, fids_merged, fids_invalid
# for each fire
allfires.update_t_allfires(t)  # update t
allfires.reset_newpixels()     # reset newpixels

# %% [markdown]
# Read_AFP

# %%
# read 
afp_SNPP = FireIO.read_AFP(t,src='SNPP',nrt=False,region=region)
afp_SNPPNRT = FireIO.read_AFP(t,src='SNPP',nrt=True,region=region)
afp_NOAA20 = FireIO.read_AFP(t,src='NOAA20',nrt=False,region=region)

# %%
# convert to gdf (for plotting)
gdf_SNPP = gpd.GeoDataFrame(afp_SNPP, geometry=gpd.points_from_xy(afp_SNPP.Lon, afp_SNPP.Lat))
gdf_SNPPNRT = gpd.GeoDataFrame(afp_SNPPNRT, geometry=gpd.points_from_xy(afp_SNPPNRT.Lon, afp_SNPPNRT.Lat))
gdf_NOAA20 = gpd.GeoDataFrame(afp_NOAA20, geometry=gpd.points_from_xy(afp_NOAA20.Lon, afp_NOAA20.Lat))

# %%
# plot
fig,ax=plt.subplots(ncols=3,figsize=(20,6))
gdf_SNPP.plot(ax=ax[0],facecolor='r',edgecolor='none',alpha=0.5)
ax[0].set(xlim=(regbox[0],regbox[2]),ylim=(regbox[1],regbox[3]),title='SNPP ('+str(len(afp_SNPP))+')')
gdf_SNPPNRT.plot(ax=ax[1],facecolor='b',edgecolor='none',alpha=0.5)
ax[1].set(xlim=(regbox[0],regbox[2]),ylim=(regbox[1],regbox[3]),title='SNPPNRT ('+str(len(afp_SNPPNRT))+')')
gdf_NOAA20.plot(ax=ax[2],facecolor='g',edgecolor='none',alpha=0.5)
_=ax[2].set(xlim=(regbox[0],regbox[2]),ylim=(regbox[1],regbox[3]),title='NOAA20 ('+str(len(afp_NOAA20))+')')

# %% [markdown]
# Fire exansion/creation

# %%
# Use SNPP data for example
afp = afp_SNPP


allfires = FireMain.Fire_expand_rtree(allfires,afp,fids_ea)

print(allfires.number_of_fires)
# Out:
# 42

# %%
# may test details within Fire_expand_rtree
# afp_loc = list(zip(afp.Lat, afp.Lon))

# %% [markdown]
# Fire merging

# %%
fids_ne = allfires.fids_ne                         # new or expanded fires id
fids_ea = sorted(set(fids_ea+allfires.fids_new))   # existing active fires (new fires included)
fids_sleep = allfires.fids_sleeper

# %%
allfires = FireMain.Fire_merge_rtree(allfires,fids_ne,fids_ea,fids_sleep)

# %% [markdown]
# Fire type update

# %%
from FireConsts import dirpjdata,FTYP_opt,FTYP_preset
allfires.updateftypes(opt=FTYP_opt,presetftype=FTYP_preset)

# %% [markdown]
# Single fire test

# %%
allfires.fires[16].hull

# %% [markdown]
# ### Time forward test

# %%
t = FireObj.t_nb(t,nb='next')

# %%
# 1. record existing active fire ids (for the previous time step)
fids_ea = allfires.fids_active

# 2. update allfires and fire object changes due to temporal progression
# all fires
allfires.update_t(t)           # update t for allfires
allfires.reset_fids_updated()  # reset fids_expanded, fids_new, fids_merged, fids_invalid
# for each fire
allfires.update_t_allfires(t)  # update t
allfires.reset_newpixels()     # reset newpixels

# %%
afp = FireIO.read_AFP(t,src='SNPP',nrt=False,region=region)

# %%
allfires = FireMain.Fire_expand_rtree(allfires,afp,fids_ea)
print(allfires.number_of_fires)
# Out:
# 60

# %%
fids_ne = allfires.fids_ne                         # new or expanded fires id
fids_ea = sorted(set(fids_ea+allfires.fids_new))   # existing active fires (new fires included)
fids_sleep = allfires.fids_sleeper
allfires = FireMain.Fire_merge_rtree(allfires,fids_ne,fids_ea,fids_sleep)

# %%
allfires.fires[16].hull

# %% [markdown]
# ## Single fire simulation
# Run FireMain.py by setting:
#
# ```
# tst=(2021,7,13,'AM')
# ted=(2021,9,15,'PM')
# region = ('Dixie',[-121.6,39.8,-120.5,40.6])
# Fire_Forward(tst=tst,ted=ted,restart=True,region=region,src='SNPP')
# ```

# %%
import FireObj
import importlib
importlib.reload(FireObj)
# Out:
# <module 'FireObj' from '/Users/yangchen/GoogleDrive/My/My.Research/UCI/ProjectsFull/California.fire/Code/fireatlas/FireObj.py'>

# %%
t = (2021,8,6,'PM')

# %%
allfires = FireIO.load_fobj(t)

# %%
# for f in allfires.fires:
#     print(f.fireID, f.farea)

# %%
f = allfires.fires[0]

# %%
from shapely.geometry import Point
import geopandas as gpd
mp = [Point(p.lon,p.lat) for p in f.flinepixels]
gdf_flp = gpd.GeoSeries(mp)

# %%
fig,ax=plt.subplots(ncols=1,figsize=(15,10))
gpd.GeoSeries(f.hull).plot(ax=ax,facecolor='none',edgecolor='grey')
_=gpd.GeoSeries(f.newlocsMP).plot(ax=ax,color='grey',alpha=0.2)
_=gpd.GeoSeries(f.fline).plot(ax=ax,facecolor='none',edgecolor='blue')
_=gdf_flp.plot(ax=ax,color='r',alpha=0.9)

# %% [markdown]
# Sensitifity of fire line to the value of parameter fpbuffer

# %%
# fpbuffer changed from 200m to 500m
fig,ax=plt.subplots(ncols=1,figsize=(15,10))
gpd.GeoSeries(f.hull).plot(ax=ax,facecolor='none',edgecolor='grey')
_=gpd.GeoSeries(f.newlocsMP).plot(ax=ax,color='grey',alpha=0.2)
_=gpd.GeoSeries(f.fline).plot(ax=ax,facecolor='none',edgecolor='blue')
_=gdf_flp.plot(ax=ax,color='r',alpha=0.9)

# %%
# fpbuffer changed from 200m to 1000m
fig,ax=plt.subplots(ncols=1,figsize=(15,10))
gpd.GeoSeries(f.hull).plot(ax=ax,facecolor='none',edgecolor='grey')

f_pt = FireIO.load_fobj(FireObj.t_nb(t,nb='previous')).fires[0]
gpd.GeoSeries(f_pt.hull).plot(ax=ax,facecolor='none',edgecolor='black')

_=gpd.GeoSeries(f.newlocsMP).plot(ax=ax,color='grey',alpha=0.2)
_=gpd.GeoSeries(f.fline).plot(ax=ax,facecolor='none',edgecolor='blue')
_=gdf_flp.plot(ax=ax,color='r',alpha=0.9)

# %% [markdown]
# ## Snapshot

# %%
# set time
# t = (2021,8,1,'AM')
t = (2021,8,6,'PM')

from datetime import date
d = date(*t[:-1])

# %%
allfires = FireIO.load_fobj(t)

# %%
heritage = dict(FireIO.load_fobj(t).heritages)

# %%
dd = {'fireID':'int',                  # id
      'mergid':'int',               # this is the id in the large fire database
      #'clat':'float',               # centroid latitude   -> centroid[0]
      #'clon':'float',               # centroid longitude  -> centroid[1]
      'ftype':'int',                # fire type
      'isactive':'int',             # active status
      't_inactive':'int',           # how long has it been inactive
      'isignition':'int',           # is this a new ignition?
      'invalid':'int',              # invalid status
      'n_pixels':'int',             # number of total pixels
      'n_newpixels':'int',          # number of new pixels
      'farea':'float',              # fire size
      'fperim':'float',             # fire perimeter length
      'flinelen':'float',           # active fire front line length
      'duration':'float',           # fire duration
      'pixden':'float',             # fire pixel density
      'meanFRP':'float',            # mean FRP of the new fire pixels
      'tst_year':'int',             # t_st[0]
      'tst_month':'int',
      'tst_day':'int',
      'tst_ampm':'str',
      'ted_year':'int',             # t_ed[0]
      'ted_month':'int',
      'ted_day':'int',
      'ted_ampm':'str',
      'ted_doy':'int',
      }

# %%
gdf = gpd.GeoDataFrame(columns=list(dd.keys()),crs='epsg:4326', geometry=[])

# %%
gdf = gdf.set_index('fireID')

# %%
for fid in (allfires.fids_active):
    #gdf.loc[fid,'clat'] = allfires.fires[fid].centroid[0]
    #gdf.loc[fid,'clon'] = allfires.fires[fid].centroid[1]
    gdf.loc[fid,'mergid'] = fid
    gdf.loc[fid,'ftype'] = allfires.fires[fid].ftype
    gdf.loc[fid,'isactive'] = 1
    gdf.loc[fid,'invalid'] = 0
    gdf.loc[fid,'isignition'] = allfires.fires[fid].isignition
    gdf.loc[fid,'t_inactive'] = int(allfires.fires[fid].t_inactive)
    gdf.loc[fid,'n_pixels'] = int(allfires.fires[fid].n_pixels)
    gdf.loc[fid,'n_newpixels'] = int(allfires.fires[fid].n_newpixels)
    gdf.loc[fid,'farea'] = allfires.fires[fid].farea
    gdf.loc[fid,'fperim'] = allfires.fires[fid].fperim
    gdf.loc[fid,'flinelen'] = allfires.fires[fid].flinelen
    gdf.loc[fid,'duration'] = allfires.fires[fid].duration
    gdf.loc[fid,'pixden'] = allfires.fires[fid].pixden
    gdf.loc[fid,'meanFRP'] = allfires.fires[fid].meanFRP
    gdf.loc[fid,'tst_year'] = int(allfires.fires[fid].t_st[0])
    gdf.loc[fid,'tst_month'] = int(allfires.fires[fid].t_st[1])
    gdf.loc[fid,'tst_day'] = int(allfires.fires[fid].t_st[2])
    gdf.loc[fid,'tst_ampm'] = allfires.fires[fid].t_st[3]
    gdf.loc[fid,'ted_year'] = int(allfires.fires[fid].t_ed[0])
    gdf.loc[fid,'ted_month'] = int(allfires.fires[fid].t_ed[1])
    gdf.loc[fid,'ted_day'] = int(allfires.fires[fid].t_ed[2])
    gdf.loc[fid,'ted_ampm'] = allfires.fires[fid].t_ed[3]
    gdf.loc[fid,'ted_doy'] = allfires.fires[fid].cdoy

    # change mergeid in case fire has been merged
    if fid in heritage.keys():
        gdf.loc[fid,'mergid'] = heritage[fid]

# %%
for fid in allfires.fids_active:
    fhull = allfires.fires[fid].hull
    if fhull is not None:
        if fhull.geom_type == 'MultiPolygon':
            gdf.loc[fid,'geometry'] = gpd.GeoDataFrame(geometry=[fhull]).geometry.values
        else:
            gdf.loc[fid,'geometry'] = fhull

# %% [markdown]
# ## Single fire series (sfs)

# %%
tst=(2021,7,13,'AM')
# ted=(2021,9,15,'PM')
ted=(2021,7,22,'PM')

# %%
import FireIO

falim = 4
# read allfires
allfires = FireIO.load_fobj(ted)

# extract large valid fires
# large_ids = [allfires.fires[i].fireID for i in range(allfires.number_of_validfires) if allfires.fires[i].farea > falim]
large_ids = [f.fireID for f in allfires.validfires if f.farea > falim]

# remove fires merged to other fires (is this really needed? all validfires have not been merged to other fires... )
skip,merge_ids = zip(*FireIO.load_fobj(ted).heritages)
large_ids = [fire for fire in large_ids if fire not in skip]

# %%
fid = 0
f = allfires.fires[fid]
start_end = (f.t_st,f.t_ed)

# %%
fh = [fid]
for h in allfires.heritages:
    if h[1] == fid:
        fh.append(h[0])

# %%
# import FireGpkg_sfs

# gdf_sf = FireGpkg_sfs.make_fire_history(fid, start_end)
# gdf_sf_fline = FireGpkg_sfs.make_fire_history_fline_NFP(fid, start_end,layer='fireline')
# gdf_sf_NFP = FireGpkg_sfs.make_fire_history_fline_NFP(fid, start_end,layer='newfirepix')

# gdf_sf.plot(facecolor='none',edgecolor='r')

# %% [markdown]
# > make_fire_history

# %%
tst,ted = start_end
endloop = False  # flag to control the ending of the loop
t_inact = 0      # counts the days a fire is inactive before it spreads again
t = list(tst)    # t is the time (year,month,day,ampm) for each step
while endloop == False:
    # read daily gdf
    gdf_perim = FireIO.load_gpkgobj(t,layer='perimeter')
#     print(t,len(gdf_perim))    
    if gdf_perim is None:
        t = FireObj.t_nb(t,nb='next')
        t_inact += 0.5 # half-daily time steps
        continue
        
    gdf_1d = gdf_perim[gdf_perim.mergid.isin(fh)]  # here we need to enter merge id instead of index
    
    print(t,len(gdf_1d))
    gdf_1d = gdf_1d[gdf_1d.n_newpixels > 0]
    if len(gdf_1d) == 0:
        t = FireObj.t_nb(t,nb='next')
        t_inact += 0.5 # half-daily time steps
        continue

    if len(gdf_1d) > 1:
        print('merge ... ')
        gdf_1d = FireGpkg_sfs.merge_fires(gdf_1d, fid, tst, t)
        
    gdf_1d.index = [FireObj.t2dt(t)]
    
    # append daily row to gdf_all
    if FireObj.t_dif(t,tst)==0:
        gdf_all = gdf_1d
    else:
        gdf_all = gdf_all.append(gdf_1d)

            
    if FireObj.t_dif(t,ted)<=0:
        endloop = True
        
#     print(t,len(gdf_1d),end=';')
    t = FireObj.t_nb(t,nb='next')
# Out:
# [2021, 7, 14, 'AM'] 1
# [2021, 7, 14, 'PM'] 1
# [2021, 7, 15, 'AM'] 1
# [2021, 7, 15, 'PM'] 1
# [2021, 7, 16, 'AM'] 1
# [2021, 7, 16, 'PM'] 1
# [2021, 7, 17, 'AM'] 1
# [2021, 7, 17, 'PM'] 1
# [2021, 7, 18, 'AM'] 1
# [2021, 7, 18, 'PM'] 1
# [2021, 7, 19, 'AM'] 1
# [2021, 7, 19, 'PM'] 1
# [2021, 7, 20, 'AM'] 1
# [2021, 7, 20, 'PM'] 1
# [2021, 7, 21, 'AM'] 1
# [2021, 7, 21, 'PM'] 1
# [2021, 7, 22, 'AM'] 1
# [2021, 7, 22, 'PM'] 1

# %%
gdf_perim = FireIO.load_gpkgobj(t,layer='perimeter')

# %%
gdf_1d = gdf_perim[gdf_perim.mergid.isin(fh)]

# %%
gdf_1d = gdf_1d[gdf_1d.n_newpixels > 0]

# %%
gdf_1d.plot()

# %%
gdf_1d = FireGpkg_sfs.merge_fires(gdf_1d, fid, tst, t)

# %%
gdf_1d
# Out:
#                                                  geometry  ftype  isactive  \
# mergid
# 0       MULTIPOLYGON (((-120.95942 40.00282, -120.9652...      2         1
#
#         t_inactive  isignition  invalid  n_pixels  n_newpixels       farea  \
# mergid
# 0                0           0        0      7051         1295  678.499058
#
#           fperim  ...  tst_year  tst_month  tst_day  tst_ampm  ted_year  \
# mergid            ...
# 0       1.858541  ...      2021          7       14        AM      2021
#
#         ted_month  ted_day ted_ampm  ted_doy  mergid
# mergid
# 0            2021     2021       AM      204       0
#
# [1 rows x 24 columns]

# %% [markdown]
# > save_gdf_trng & save_gdf_1fire

# %%
# ted = (2021,7,22,'PM')
ted = (2021,9,15,'PM')
falim = 4

# %%
import FireIO

# read allfires
allfires = FireIO.load_fobj(ted)

# extract large valid fires
# large_ids = [allfires.fires[i].fireID for i in range(allfires.number_of_validfires) if allfires.fires[i].farea > falim]
large_ids = [f.fireID for f in allfires.validfires if f.farea > falim]

# remove fires merged to other fires (is this really needed? all validfires have not been merged to other fires... )
skip,merge_ids = zip(*FireIO.load_fobj(ted).heritages)
large_ids = [fire for fire in large_ids if fire not in skip]

# %%
fid = large_ids[0]

# %%
f = allfires.fires[fid]

fh = [fid]
for h in allfires.heritages:
    if h[1] == fid:
        fh.append(h[0])

# %%
start_end = (f.t_st,f.t_ed)

# %%
gdf_sf = FireGpkg_sfs.make_fire_history(fid, start_end, fh)

# %%
gdf_sf.plot(facecolor='none',edgecolor='r')

# %%
gdf_sf.iloc[20].geometry

# %% [markdown]
# > read and test output

# %%
f0read_perimeter = FireIO.load_gpkgsfs(ted,0,layer='perimeter')

# %%
f0read_fireline = FireIO.load_gpkgsfs(ted,0,layer='fireline')

# %%
f0read_newfirepix = FireIO.load_gpkgsfs(ted,0,layer='newfirepix')

# %%
fig,ax=plt.subplots(ncols=1,figsize=(15,10))
f0read_perimeter.plot(ax=ax,facecolor='none',edgecolor=pltcm.jet(f0read_perimeter.duration/f0read_perimeter.duration.max()))

# %%
f0read_newfirepix.iloc[[28]]
# Out:
#                      mergid                                           geometry
# index
# 2021-07-29T00:00:00     0.0  MULTIPOINT (-121.24713 40.20106, -121.20690 40...

# %%
f0read_fireline.iloc[[30]]
# Out:
#                      mergid                                           geometry
# index
# 2021-07-29T00:00:00     0.0  MULTILINESTRING ((-121.40983 40.03754, -121.41...

# %%
f0read_perimeter.iloc[[28]]
# Out:
#                      mergid  ftype  isactive  t_inactive  isignition  invalid  \
# index
# 2021-07-29T00:00:00       0      2         1           0           0        0
#
#                      n_pixels  n_newpixels        farea    fperim  ...  \
# index                                                              ...
# 2021-07-29T00:00:00     11336          504  1055.183478  2.712601  ...
#
#                      tst_year  tst_month  tst_day  tst_ampm  ted_year  \
# index
# 2021-07-29T00:00:00      2021          7       14        AM      2021
#
#                      ted_month  ted_day ted_ampm  ted_doy  \
# index
# 2021-07-29T00:00:00          7       29       AM      210
#
#                                                               geometry
# index
# 2021-07-29T00:00:00  MULTIPOLYGON (((-121.37765 39.86628, -121.3785...
#
# [1 rows x 24 columns]

# %%
fig,ax=plt.subplots(ncols=1,figsize=(15,10))
f0read_perimeter.iloc[[27]].plot(ax=ax,facecolor='none',edgecolor='0.2')
f0read_perimeter.iloc[[28]].plot(ax=ax,facecolor='none',edgecolor='k')
f0read_fireline.iloc[[30]].plot(ax=ax,color='r')
f0read_newfirepix.iloc[[28]].plot(ax=ax)

# %%
fig,ax=plt.subplots(ncols=1,figsize=(15,10))
# f0read_perimeter.plot(ax=ax,facecolor='none',edgecolor=pltcm.jet(f0read_perimeter.duration/f0read_perimeter.duration.max()))
f0read_fireline.plot(ax=ax,color='0.5')
# f0read_newfirepix.plot(ax=ax,color=pltcm.jet(f0read_fireline.duration/f0read_perimeter.duration.max()),markersize=1)
# _=gpd.GeoSeries(f.newlocsMP).plot(ax=ax,color='grey',alpha=0.2)
# _=gpd.GeoSeries(f.fline).plot(ax=ax,facecolor='none',edgecolor='blue')
# _=gdf_flp.plot(ax=ax,color='r',alpha=0.9)

# %% [markdown]
# ## VIIRS active fire reading

# %%
import importlib
importlib.reload(FireIO)
# Out:
# <module 'FireIO' from '/Users/yangchen/GoogleDrive/My/My.Research/UCI/ProjectsFull/California.fire/Code/fireatlas/FireIO.py'>

# %%
import ycpy
ycpy.util.nowarn()

# %%
import FireObj
import FireIO
import FireConsts
import FireMain

# %%
t = (2021,8,1,'AM')

# %%
region=('Dixie',[-121.6,39.8,-120.5,40.6])

# %%
vlist = FireIO.read_AFP((2021,8,1,'AM'),src='SNPP',nrt=False,region=('Dixie',[-121.6,39.8,-120.5,40.6]))

# %%
vlist = FireIO.read_AFP((2021,8,1,'AM'),src='NOAA20',nrt=False,region=('Dixie',[-121.6,39.8,-120.5,40.6]))

# %%
vlist = FireIO.read_AFP((2020,8,1,'AM'),src='NOAA20',nrt=True,region=('Dixie',[-121.6,39.8,-120.5,40.6]))
# Out:
# /Users/yangchen/Jacaranda/ProjectData/FEDStest/ExtData/VJ114IMGTDL/J1_VIIRS_C2_Global_VJ114IMGTDL_NRT_2020214.txt

# %%
# df = FireIO.read_VJ114IMGTDL((2020,8,1,'AM'))
# Out:
# /Users/yangchen/Jacaranda/ProjectData/FEDStest/ExtData/VJ114IMGTDL/J1_VIIRS_C2_Global_VJ114IMGTDL_NRT_2020214.txt

# %%
df_SNPP = FireIO.read_AFPSNPP(t,region)

# %%
df_NOAA20 = FireIO.read_AFPNOAA20(t,region)

# %%
vlist = pd.concat([df_NOAA20,df_SNPP],ignore_index=True)

# %%
df_SNPPNRT = FireIO.read_AFPSNPPNRT(t,region)

# %%
df_NOAA20NRT = FireIO.read_AFPNOAA20NRT((2020,8,1,'AM'),region)

# %%
df = FireIO.read_VNP14IMGTDL(t)

# %%
df = FireIO.AFP_setampm(df)

# %%
shp_Reg = FireIO.get_reg_shp(region[1])
df = FireIO.AFP_regfilter(df,shp_Reg)

# %%
df
# Out:
#              YYYYMMDD_HHMM       Lat        Lon    DS    DT confidence    FRP  \
# 37088  2021-08-01 10:13:00  39.93178 -121.15630  0.46  0.39    nominal   0.66
# 37634  2021-08-01 10:13:00  40.19138 -121.24726  0.45  0.39    nominal   1.18
# 37638  2021-08-01 10:13:00  40.19388 -121.24094  0.45  0.39    nominal   1.18
# 37646  2021-08-01 10:13:00  40.16607 -121.17286  0.45  0.39    nominal   1.04
# 37648  2021-08-01 10:13:00  40.19835 -121.24498  0.45  0.39    nominal   0.50
# ...                    ...       ...        ...   ...   ...        ...    ...
# 103493 2021-08-01 21:38:00  39.93541 -121.08817  0.14  0.37    nominal  62.96
# 103494 2021-08-01 21:38:00  40.06963 -121.10075  0.14  0.37    nominal   4.52
# 103495 2021-08-01 21:38:00  39.93645 -121.08968  0.14  0.37    nominal  61.98
# 103496 2021-08-01 21:38:00  40.06541 -121.15936  0.14  0.37       high  30.03
# 103497 2021-08-01 21:38:00  39.93594 -121.09697  0.14  0.37    nominal  61.98
#
#        daynight ampm
# 37088         N   AM
# 37634         N   AM
# 37638         N   AM
# 37646         N   AM
# 37648         N   AM
# ...         ...  ...
# 103493        D   PM
# 103494        D   PM
# 103495        D   PM
# 103496        D   PM
# 103497        D   PM
#
# [184 rows x 9 columns]

# %%
df_SNPP
# Out:
#           Lat         Lon   FRP   Sat        DT        DS       YYYYMMDD_HHMM  \
# 0   40.177837 -120.820419  0.34  SNPP  0.464274  0.394447 2021-08-01 10:12:00
# 1   40.198353 -121.244980  0.51  SNPP  0.448655  0.388229 2021-08-01 10:12:00
# 2   40.193882 -121.240936  1.18  SNPP  0.448846  0.388306 2021-08-01 10:12:00
# 3   40.191376 -121.247261  1.18  SNPP  0.448655  0.388229 2021-08-01 10:12:00
# 4   40.166073 -121.172859  1.00  SNPP  0.451559  0.389395 2021-08-01 10:12:00
# 5   40.106773 -120.981117  2.73  SNPP  0.459304  0.392483 2021-08-01 10:12:00
# 6   40.105675 -120.975479  2.27  SNPP  0.459516  0.392567 2021-08-01 10:12:00
# 7   40.103317 -120.982635  2.73  SNPP  0.459304  0.392483 2021-08-01 10:12:00
# 8   40.102207 -120.976929  2.27  SNPP  0.459516  0.392567 2021-08-01 10:12:00
# 9   40.099815 -120.983917  0.88  SNPP  0.459304  0.392483 2021-08-01 10:12:00
# 10  40.097595 -120.972496  3.32  SNPP  0.459728  0.392651 2021-08-01 10:12:00
# 11  40.107651 -121.043633  4.92  SNPP  0.457004  0.391569 2021-08-01 10:12:00
# 12  40.106571 -121.038055  4.92  SNPP  0.457211  0.391651 2021-08-01 10:12:00
# 13  40.094093 -120.973755  3.32  SNPP  0.459728  0.392651 2021-08-01 10:12:00
# 14  40.105507 -121.032562  0.88  SNPP  0.457419  0.391734 2021-08-01 10:12:00
# 15  40.093014 -120.968208  2.32  SNPP  0.459940  0.392735 2021-08-01 10:12:00
# 16  40.078217 -120.892296  1.18  SNPP  0.462956  0.393928 2021-08-01 10:12:00
# 17  40.103039 -121.039124  5.80  SNPP  0.457211  0.391651 2021-08-01 10:12:00
# 18  40.101971 -121.033646  6.74  SNPP  0.457419  0.391734 2021-08-01 10:12:00
# 19  40.104115 -121.044693  5.80  SNPP  0.457004  0.391569 2021-08-01 10:12:00
# 20  40.076836 -120.904488  1.66  SNPP  0.462520  0.393756 2021-08-01 10:12:00
# 21  40.073399 -120.906181  1.66  SNPP  0.462520  0.393756 2021-08-01 10:12:00
# 22  40.054756 -120.868652  1.64  SNPP  0.464274  0.394447 2021-08-01 10:12:00
# 23  40.147804 -121.406342  2.21  SNPP  0.443817  0.386277 2021-08-01 10:12:00
# 24  40.145317 -121.412613  0.88  SNPP  0.443636  0.386203 2021-08-01 10:12:00
# 25  40.141830 -121.413635  0.88  SNPP  0.443636  0.386203 2021-08-01 10:12:00
# 26  40.033054 -121.402115  1.14  SNPP  0.445464  0.386943 2021-08-01 10:12:00
# 27  39.961388 -121.174644  8.66  SNPP  0.454549  0.390591 2021-08-01 10:12:00
# 28  39.941078 -121.087914  2.22  SNPP  0.457835  0.391899 2021-08-01 10:12:00
# 29  39.940018 -121.082359  2.22  SNPP  0.458044  0.391982 2021-08-01 10:12:00
# 30  39.943340 -121.158241  1.78  SNPP  0.455361  0.390915 2021-08-01 10:12:00
# 31  39.943722 -121.179657  3.54  SNPP  0.454549  0.390591 2021-08-01 10:12:00
# 32  39.942726 -121.174454  3.54  SNPP  0.454751  0.390672 2021-08-01 10:12:00
# 33  39.941738 -121.169319  3.85  SNPP  0.454954  0.390753 2021-08-01 10:12:00
# 34  39.940769 -121.164276  3.85  SNPP  0.455157  0.390834 2021-08-01 10:12:00
# 35  39.939194 -121.175476  1.92  SNPP  0.454751  0.390672 2021-08-01 10:12:00
# 36  39.938198 -121.170303  0.99  SNPP  0.454954  0.390753 2021-08-01 10:12:00
# 37  39.934345 -121.150261  1.75  SNPP  0.455769  0.391078 2021-08-01 10:12:00
# 38  39.938648 -121.192047  2.38  SNPP  0.454145  0.390430 2021-08-01 10:12:00
# 39  39.937649 -121.186844  2.38  SNPP  0.454347  0.390510 2021-08-01 10:12:00
# 40  39.931778 -121.156303  0.63  SNPP  0.455565  0.390996 2021-08-01 10:12:00
# 41  39.934124 -121.187897  1.89  SNPP  0.454347  0.390510 2021-08-01 10:12:00
# 42  39.929180 -121.162170  1.70  SNPP  0.455361  0.390915 2021-08-01 10:12:00
# 43  39.928226 -121.157227  1.70  SNPP  0.455565  0.390996 2021-08-01 10:12:00
#
#    ampm
# 0    AM
# 1    AM
# 2    AM
# 3    AM
# 4    AM
# 5    AM
# 6    AM
# 7    AM
# 8    AM
# 9    AM
# 10   AM
# 11   AM
# 12   AM
# 13   AM
# 14   AM
# 15   AM
# 16   AM
# 17   AM
# 18   AM
# 19   AM
# 20   AM
# 21   AM
# 22   AM
# 23   AM
# 24   AM
# 25   AM
# 26   AM
# 27   AM
# 28   AM
# 29   AM
# 30   AM
# 31   AM
# 32   AM
# 33   AM
# 34   AM
# 35   AM
# 36   AM
# 37   AM
# 38   AM
# 39   AM
# 40   AM
# 41   AM
# 42   AM
# 43   AM

# %%
df_SNPPNRT
# Out:
#          Lat        Lon   FRP   Sat    DT    DS       YYYYMMDD_HHMM ampm
# 0   39.93178 -121.15630  0.66  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 1   40.19138 -121.24726  1.18  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 2   40.19388 -121.24094  1.18  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 3   40.16607 -121.17286  1.04  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 4   40.19835 -121.24498  0.50  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 5   40.10567 -120.97548  2.29  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 6   40.17784 -120.82042  0.33  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 7   40.10677 -120.98112  2.73  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 8   40.10765 -121.04363  4.90  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 9   40.09760 -120.97250  3.32  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 10  40.10657 -121.03806  4.90  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 11  40.09982 -120.98392  0.92  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 12  40.09301 -120.96821  2.33  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 13  40.10551 -121.03256  0.86  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 14  40.09409 -120.97375  3.32  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 15  40.10221 -120.97693  2.29  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 16  40.10411 -121.04469  5.80  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 17  40.10197 -121.03365  6.68  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 18  40.07684 -120.90449  1.68  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 19  40.10304 -121.03912  5.80  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 20  40.10332 -120.98264  2.73  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 21  40.07822 -120.89230  1.12  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 22  40.14183 -121.41364  0.89  SNPP  0.39  0.44 2021-08-01 10:13:00   AM
# 23  40.14532 -121.41261  0.89  SNPP  0.39  0.44 2021-08-01 10:13:00   AM
# 24  40.14780 -121.40634  2.23  SNPP  0.39  0.44 2021-08-01 10:13:00   AM
# 25  40.05476 -120.86865  1.67  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 26  40.07340 -120.90618  1.68  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 27  39.94108 -121.08791  2.25  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 28  39.96139 -121.17464  8.67  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 29  39.94002 -121.08236  2.25  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 30  40.03305 -121.40211  1.14  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 31  39.94273 -121.17445  3.52  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 32  39.94372 -121.17966  3.52  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 33  39.94334 -121.15824  1.82  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 34  39.93820 -121.17030  0.98  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 35  39.93919 -121.17548  1.88  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 36  39.93435 -121.15026  1.73  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 37  39.94077 -121.16428  3.87  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 38  39.93765 -121.18684  2.38  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 39  39.94174 -121.16932  3.87  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 40  39.93865 -121.19205  2.38  SNPP  0.39  0.45 2021-08-01 10:13:00   AM
# 41  39.92823 -121.15723  1.68  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 42  39.92918 -121.16217  1.68  SNPP  0.39  0.46 2021-08-01 10:13:00   AM
# 43  39.93412 -121.18790  1.92  SNPP  0.39  0.45 2021-08-01 10:13:00   AM

# %%
from shapely.geometry import multipoint

# %%
import geopandas as gpd

# %%
mp_SNPPNRT = gpd.points_from_xy(df_SNPPNRT.Lon, df_SNPPNRT.Lat)

# %%
gpd.GeoSeries(mp_SNPPNRT).plot()

# %%
mp_SNPP = gpd.points_from_xy(df_SNPP.Lon, df_SNPP.Lat)

# %%
gpd.GeoSeries(mp_SNPP).plot()

# %%
import FireIO

# %%
import pickle

# %%
fnm = '/Users/yangchen/Jacaranda/ProjectData/FEDStest/Output/Creek/2020/Serialization/20201105PM_full.pkl'
with open(fnm,'rb') as f:
    allfires_full = pickle.load(f)

# %%
allfires_full.number_of_fires,allfires_full.number_of_activefires,allfires_full.number_of_validfires
# Out:
# (21, 1, 3)

# %%
allfires_full.fids_valid,allfires_full.fids_active,allfires_full.fids_sleeper
# Out:
# ([0, 19, 20], [0], [20])

# %%
for f in allfires_full.validfires:
    print(f.fireID,f.farea)
# Out:
# 0 1852.431478195574
# 19 3.1839913156310504
# 20 0.141

# %%
f = allfires_full.fires[0]

# %%
from FireConsts import FTYP_CA

# %%
dictmp = [2,'Forest']

# %%
type(dictmp[1])
# Out:
# str

# %%
fnm = '/Users/yangchen/Jacaranda/ProjectData/FEDStest/Output/Creek/2020/Serialization/20201105PM.pkl'
with open(fnm,'rb') as f:
    allfires = pickle.load(f)

# %%
allfires.number_of_fires,allfires.number_of_activefires,allfires.number_of_validfires
# Out:
# (2, 1, 2)

# %%
f19 = allfires_full.fires[19]

# %%
f19.t_st,f19.t_ed
# Out:
# ([2020, 9, 26, 'AM'], [2020, 10, 10, 'AM'])

# %%
import geopandas as gpd

# %%
f0 = allfires_full.fires[0]

# %%
fig,ax=plt.subplots(figsize=(15,20))
gpd.GeoSeries(f0.hull).plot(ax=ax,facecolor='none',edgecolor='r')
gpd.GeoSeries(f19.hull).plot(ax=ax,facecolor='none',edgecolor='b')
