# %%
# !pip install -e .. -q

# ^^^ restart kernel and re-comment the above line after running this!

# %%
from fireatlas import FireRunDaskCoordinator, DataCheckUpdate
from fireatlas.FireRunDaskCoordinator import Run
import s3fs
from pathlib import Path
import geopandas as gpd

# %%
s3 = s3fs.S3FileSystem(anon=False)

# %%
## OPTIONAL: Print list of available .gpkg files to bound FEDS runs. 
# region_files = s3.glob('s3://maap-ops-workspace/shared/gsfc_landslides/FEDSinput/Shapefiles/*.gpkg')
# region_names = list(reversed([Path(path).stem for path in region_files]))
# print(region_names)

# %% [markdown]
# In the below line specify the region name you want to run and the either the bbox or shapefile you want to use for the run.
#
# Custom geometry example:
#
# `Run(region=["Central_America_Example","Central_America.gpkg"],tst=[2025,5,31,'PM'],ted=[2025,6,2,'AM'],copy_to_veda=False)`
#
# bbox example:
#
# `Run(region=["Central_America_Example",[-118.590821,3.423844,-51.090821,32.434051]],tst=[2025,5,31,'PM'],ted=[2025,6,2,'AM'],copy_to_veda=False)`
#
# NOTE: `copy_to_veda` should always be set to `False`.

# %%
region_name = "Central_America_ADE_Example"
bbox = [-118.590821,3.423844,-51.090821,32.434051]

# %%
Run(region=[region_name,bbox],tst=[2025,5,15,'PM'],ted=[2025,5,18,'AM'],copy_to_veda=False)
# Out:
# 2025-09-04 05:13:40,126 - fireatlas.FireLog - INFO - ------------- Starting full run from tst=[2025, 5, 15, 'PM'] to ted=[2025, 5, 18, 'AM'] -------------
# SYSTEM INFO
# -----------
# python     : 3.10.13 | packaged by conda-forge | (main, Oct 26 2023, 18:07:37) [GCC 12.3.0]
# executable : /opt/conda/envs/pangeo/bin/python
# machine    : Linux-5.4.0-1021-aws-fips-x86_64-with-glibc2.31
#
# GEOS, GDAL, PROJ INFO
# ---------------------
# GEOS       : 3.11.2
# GEOS lib   : None
# GDAL       : 3.7.0
# GDAL data dir: /opt/conda/envs/pangeo/share/gdal
# PROJ       : 9.2.0
# PROJ data dir: /opt/conda/envs/pangeo/share/proj
#
# PYTHON DEPENDENCIES
# -------------------
# geopandas  : 0.14.4
# numpy      : 1.26.4
# pandas     : 2.2.2
# pyproj     : 3.5.0
# shapely    : 2.0.1
# fiona      : 1.9.4
# geoalchemy2: None
# geopy      : 2.4.1
# matplotlib : 3.7.3
# mapclassify: 2.6.1
# pygeos     : None
# pyogrio    : 0.6.0
# psycopg2   : None
# pyarrow    : 14.0.1
# rtree      : 1.2.0
# 2025-09-04 05:13:41,069 - fireatlas.FireLog - INFO - dask workers = 6
# 2025-09-04 05:13:42,811 - fireatlas.FireLog - INFO - logger initialized!
# 2025-09-04 05:13:42,811 - fireatlas.FireLog - INFO - logger initialized!
# 2025-09-04 05:13:42,817 - fireatlas.FireLog - INFO - logger initialized!
# 2025-09-04 05:13:42,817 - fireatlas.FireLog - INFO - logger initialized!
# 2025-09-04 05:13:42,817 - fireatlas.FireLog - INFO - logger initialized!
# 2025-09-04 05:13:42,825 - fireatlas.FireLog - INFO - logger initialized!
# 2025-09-04 05:13:44,852 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_SNPP_NRT_20250516.csv
# 2025-09-04 05:13:44,869 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_SNPP_NRT_20250516.csv
# 2025-09-04 05:13:44,892 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_SNPP_NRT_20250517.csv
# 2025-09-04 05:13:44,900 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_SNPP_NRT_20250515.csv
# 2025-09-04 05:13:44,914 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_SNPP_NRT_20250518.csv
# 2025-09-04 05:13:44,919 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_SNPP_NRT_20250517.csv
# 2025-09-04 05:13:44,931 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA20_NRT_20250516.csv
# 2025-09-04 05:13:44,940 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA20_NRT_20250515.csv
# 2025-09-04 05:13:44,970 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA20_NRT_20250517.csv
# 2025-09-04 05:13:44,979 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA20_NRT_20250518.csv
# 2025-09-04 05:13:44,981 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA20_NRT_20250517.csv
# 2025-09-04 05:13:44,983 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA20_NRT_20250516.csv
# 2025-09-04 05:13:45,092 - fireatlas.FireLog - INFO - {'LOCAL_PATH': '/projects/fireatlas/data', 'S3_PATH': 's3://maap-ops-workspace/shared/zbecker/FEDSstaging', 'INPUT_DIR': 'FEDSinput', 'PREPROCESSED_DIR': 'FEDSpreprocessed', 'OUTPUT_DIR': 'FEDSoutput-v3', 'READ_LOCATION': 's3', 'LOG_FILENAME': 'running.log', 'EARTH_RADIUS_KM': 6371.0, 'LARGEFIRE_FAREA': 4, 'EPSG_CODE': 6933, 'maxoffdays': 5, 'limoffdays': 20, 'CONNECTIVITY_CLUSTER_KM': 0.7, 'CONNECTIVITY_SLEEPER_KM': 1.0, 'valpha': 1000, 'VIIRSbuf': 187.5, 'fpbuffer': 200, 'flbuffer': 500, 'extbuffer': 1000, 'area_VI': 0.141, 'MCD64buf': 231.7, 'FIRE_SOURCE': 'VIIRS', 'FIRE_NRT': True, 'FIRE_SENSOR': 'viirs', 'remove_static_sources': True, 'remove_static_sources_sourcefile': 'VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv', 'remove_static_sources_buffer': 0.01, 'remove_static_small_fires': False, 'expand_only': False, 'number_of_multi_proc_workers': 3, 'export_to_veda': False, 'N_DASK_WORKERS': 6, 'DO_NIFC_MATCHING': False, 'NIFC_MATCHING_ACTIVE_ONLY': False, 'FTYP_OPT': 'global', 'CONT_OPT': 'global'}
# 2025-09-04 05:13:46,504 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA21_NRT_20250516.csv
# 2025-09-04 05:13:46,537 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA21_NRT_20250517.csv
# 2025-09-04 05:13:46,548 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA21_NRT_20250515.csv
# 2025-09-04 05:13:46,556 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA21_NRT_20250517.csv
# 2025-09-04 05:13:46,591 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA21_NRT_20250518.csv
# 2025-09-04 05:13:46,673 - fireatlas.FireLog - INFO - Preprocessed region is already on s3.
# 2025-09-04 05:13:46,698 - fireatlas.FireLog - INFO - preprocessing FIRMS_VIIRS_NOAA21_NRT_20250516.csv
# 2025-09-04 05:13:48,109 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.20 sec
# 2025-09-04 05:13:48,195 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.22 sec
# 2025-09-04 05:13:48,256 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.34 sec
# 2025-09-04 05:13:48,381 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.40 sec
# 2025-09-04 05:13:48,404 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.50 sec
# 2025-09-04 05:13:48,451 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.58 sec
# 2025-09-04 05:13:48,540 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.60 sec
# 2025-09-04 05:13:48,542 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.61 sec
# 2025-09-04 05:13:48,543 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.56 sec
# 2025-09-04 05:13:48,544 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.65 sec
# 2025-09-04 05:13:48,574 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.60 sec
# 2025-09-04 05:13:48,659 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.81 sec
# 2025-09-04 05:13:49,559 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.02 sec
# 2025-09-04 05:13:49,573 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.02 sec
# 2025-09-04 05:13:49,676 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.09 sec
# 2025-09-04 05:13:49,738 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.19 sec
# 2025-09-04 05:13:49,783 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.09 sec
# 2025-09-04 05:13:49,801 - fireatlas.FireLog - INFO - func:preprocess_input_file took: 3.30 sec
# 2025-09-04 05:13:52,182 - fireatlas.FireLog - INFO - func:Dask upload of 127 files took: 2.33 sec
# 2025-09-04 05:13:52,182 - fireatlas.FireLog - INFO - ------------- Done with preprocessing t -------------
# 2025-09-04 05:13:52,390 - fireatlas.FireLog - INFO - Running preprocess-region-t code for Central_America_Example at t=[2025, 5, 18, 'AM'] with source VIIRS
# 2025-09-04 05:13:52,414 - fireatlas.FireLog - INFO - {'LOCAL_PATH': '/projects/fireatlas/data', 'S3_PATH': 's3://maap-ops-workspace/shared/zbecker/FEDSstaging', 'INPUT_DIR': 'FEDSinput', 'PREPROCESSED_DIR': 'FEDSpreprocessed', 'OUTPUT_DIR': 'FEDSoutput-v3', 'READ_LOCATION': 's3', 'LOG_FILENAME': 'running.log', 'EARTH_RADIUS_KM': 6371.0, 'LARGEFIRE_FAREA': 4, 'EPSG_CODE': 6933, 'maxoffdays': 5, 'limoffdays': 20, 'CONNECTIVITY_CLUSTER_KM': 0.7, 'CONNECTIVITY_SLEEPER_KM': 1.0, 'valpha': 1000, 'VIIRSbuf': 187.5, 'fpbuffer': 200, 'flbuffer': 500, 'extbuffer': 1000, 'area_VI': 0.141, 'MCD64buf': 231.7, 'FIRE_SOURCE': 'VIIRS', 'FIRE_NRT': True, 'FIRE_SENSOR': 'viirs', 'remove_static_sources': True, 'remove_static_sources_sourcefile': 'VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv', 'remove_static_sources_buffer': 0.01, 'remove_static_small_fires': False, 'expand_only': False, 'number_of_multi_proc_workers': 3, 'export_to_veda': False, 'N_DASK_WORKERS': 6, 'DO_NIFC_MATCHING': False, 'NIFC_MATCHING_ACTIVE_ONLY': False, 'FTYP_OPT': 'global', 'CONT_OPT': 'global'}
# 2025-09-04 05:13:52,414 - fireatlas.FireLog - INFO - {'LOCAL_PATH': '/projects/fireatlas/data', 'S3_PATH': 's3://maap-ops-workspace/shared/zbecker/FEDSstaging', 'INPUT_DIR': 'FEDSinput', 'PREPROCESSED_DIR': 'FEDSpreprocessed', 'OUTPUT_DIR': 'FEDSoutput-v3', 'READ_LOCATION': 's3', 'LOG_FILENAME': 'running.log', 'EARTH_RADIUS_KM': 6371.0, 'LARGEFIRE_FAREA': 4, 'EPSG_CODE': 6933, 'maxoffdays': 5, 'limoffdays': 20, 'CONNECTIVITY_CLUSTER_KM': 0.7, 'CONNECTIVITY_SLEEPER_KM': 1.0, 'valpha': 1000, 'VIIRSbuf': 187.5, 'fpbuffer': 200, 'flbuffer': 500, 'extbuffer': 1000, 'area_VI': 0.141, 'MCD64buf': 231.7, 'FIRE_SOURCE': 'VIIRS', 'FIRE_NRT': True, 'FIRE_SENSOR': 'viirs', 'remove_static_sources': True, 'remove_static_sources_sourcefile': 'VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv', 'remove_static_sources_buffer': 0.01, 'remove_static_small_fires': False, 'expand_only': False, 'number_of_multi_proc_workers': 3, 'export_to_veda': False, 'N_DASK_WORKERS': 6, 'DO_NIFC_MATCHING': False, 'NIFC_MATCHING_ACTIVE_ONLY': False, 'FTYP_OPT': 'global', 'CONT_OPT': 'global'}
# 2025-09-04 05:13:52,415 - fireatlas.FireLog - INFO - {'LOCAL_PATH': '/projects/fireatlas/data', 'S3_PATH': 's3://maap-ops-workspace/shared/zbecker/FEDSstaging', 'INPUT_DIR': 'FEDSinput', 'PREPROCESSED_DIR': 'FEDSpreprocessed', 'OUTPUT_DIR': 'FEDSoutput-v3', 'READ_LOCATION': 's3', 'LOG_FILENAME': 'running.log', 'EARTH_RADIUS_KM': 6371.0, 'LARGEFIRE_FAREA': 4, 'EPSG_CODE': 6933, 'maxoffdays': 5, 'limoffdays': 20, 'CONNECTIVITY_CLUSTER_KM': 0.7, 'CONNECTIVITY_SLEEPER_KM': 1.0, 'valpha': 1000, 'VIIRSbuf': 187.5, 'fpbuffer': 200, 'flbuffer': 500, 'extbuffer': 1000, 'area_VI': 0.141, 'MCD64buf': 231.7, 'FIRE_SOURCE': 'VIIRS', 'FIRE_NRT': True, 'FIRE_SENSOR': 'viirs', 'remove_static_sources': True, 'remove_static_sources_sourcefile': 'VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv', 'remove_static_sources_buffer': 0.01, 'remove_static_small_fires': False, 'expand_only': False, 'number_of_multi_proc_workers': 3, 'export_to_veda': False, 'N_DASK_WORKERS': 6, 'DO_NIFC_MATCHING': False, 'NIFC_MATCHING_ACTIVE_ONLY': False, 'FTYP_OPT': 'global', 'CONT_OPT': 'global'}
# 2025-09-04 05:13:52,415 - fireatlas.FireLog - INFO - Running preprocess-region-t code for Central_America_Example at t=[2025, 5, 16, 'AM'] with source VIIRS
# 2025-09-04 05:13:52,415 - fireatlas.FireLog - INFO - Running preprocess-region-t code for Central_America_Example at t=[2025, 5, 17, 'PM'] with source VIIRS
# 2025-09-04 05:13:52,416 - fireatlas.FireLog - INFO - {'LOCAL_PATH': '/projects/fireatlas/data', 'S3_PATH': 's3://maap-ops-workspace/shared/zbecker/FEDSstaging', 'INPUT_DIR': 'FEDSinput', 'PREPROCESSED_DIR': 'FEDSpreprocessed', 'OUTPUT_DIR': 'FEDSoutput-v3', 'READ_LOCATION': 's3', 'LOG_FILENAME': 'running.log', 'EARTH_RADIUS_KM': 6371.0, 'LARGEFIRE_FAREA': 4, 'EPSG_CODE': 6933, 'maxoffdays': 5, 'limoffdays': 20, 'CONNECTIVITY_CLUSTER_KM': 0.7, 'CONNECTIVITY_SLEEPER_KM': 1.0, 'valpha': 1000, 'VIIRSbuf': 187.5, 'fpbuffer': 200, 'flbuffer': 500, 'extbuffer': 1000, 'area_VI': 0.141, 'MCD64buf': 231.7, 'FIRE_SOURCE': 'VIIRS', 'FIRE_NRT': True, 'FIRE_SENSOR': 'viirs', 'remove_static_sources': True, 'remove_static_sources_sourcefile': 'VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv', 'remove_static_sources_buffer': 0.01, 'remove_static_small_fires': False, 'expand_only': False, 'number_of_multi_proc_workers': 3, 'export_to_veda': False, 'N_DASK_WORKERS': 6, 'DO_NIFC_MATCHING': False, 'NIFC_MATCHING_ACTIVE_ONLY': False, 'FTYP_OPT': 'global', 'CONT_OPT': 'global'}
# 2025-09-04 05:13:52,416 - fireatlas.FireLog - INFO - Running preprocess-region-t code for Central_America_Example at t=[2025, 5, 15, 'PM'] with source VIIRS
# 2025-09-04 05:13:52,416 - fireatlas.FireLog - INFO - {'LOCAL_PATH': '/projects/fireatlas/data', 'S3_PATH': 's3://maap-ops-workspace/shared/zbecker/FEDSstaging', 'INPUT_DIR': 'FEDSinput', 'PREPROCESSED_DIR': 'FEDSpreprocessed', 'OUTPUT_DIR': 'FEDSoutput-v3', 'READ_LOCATION': 's3', 'LOG_FILENAME': 'running.log', 'EARTH_RADIUS_KM': 6371.0, 'LARGEFIRE_FAREA': 4, 'EPSG_CODE': 6933, 'maxoffdays': 5, 'limoffdays': 20, 'CONNECTIVITY_CLUSTER_KM': 0.7, 'CONNECTIVITY_SLEEPER_KM': 1.0, 'valpha': 1000, 'VIIRSbuf': 187.5, 'fpbuffer': 200, 'flbuffer': 500, 'extbuffer': 1000, 'area_VI': 0.141, 'MCD64buf': 231.7, 'FIRE_SOURCE': 'VIIRS', 'FIRE_NRT': True, 'FIRE_SENSOR': 'viirs', 'remove_static_sources': True, 'remove_static_sources_sourcefile': 'VIIRS_Global_flaring_d.7_slope_0.029353_2017_web_v1.csv', 'remove_static_sources_buffer': 0.01, 'remove_static_small_fires': False, 'expand_only': False, 'number_of_multi_proc_workers': 3, 'export_to_veda': False, 'N_DASK_WORKERS': 6, 'DO_NIFC_MATCHING': False, 'NIFC_MATCHING_ACTIVE_ONLY': False, 'FTYP_OPT': 'global', 'CONT_OPT': 'global'}
# 2025-09-04 05:13:52,417 - fireatlas.FireLog - INFO - Running preprocess-region-t code for Central_America_Example at t=[2025, 5, 16, 'PM'] with source VIIRS
# 2025-09-04 05:13:52,417 - fireatlas.FireLog - INFO - Running preprocess-region-t code for Central_America_Example at t=[2025, 5, 17, 'AM'] with source VIIRS
# 2025-09-04 05:13:52,823 - fireatlas.FireLog - INFO - func:read_region took: 405.36 ms
# 2025-09-04 05:13:52,823 - fireatlas.FireLog - INFO - filtering and clustering 2025-5-17 AM, VIIRS, Central_America_Example
# 2025-09-04 05:13:52,838 - fireatlas.FireLog - INFO - func:read_region took: 420.72 ms
# 2025-09-04 05:13:52,839 - fireatlas.FireLog - INFO - filtering and clustering 2025-5-16 PM, VIIRS, Central_America_Example
# 2025-09-04 05:13:52,893 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 67.05 ms
# 2025-09-04 05:13:52,965 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 125.31 ms
# 2025-09-04 05:13:52,967 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 74.06 ms
# 2025-09-04 05:13:53,041 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 74.08 ms
# 2025-09-04 05:13:53,092 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 127.61 ms
# 2025-09-04 05:13:53,232 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 139.60 ms
# 2025-09-04 05:13:54,050 - fireatlas.FireLog - INFO - func:read_region took: 1.66 sec
# 2025-09-04 05:13:54,050 - fireatlas.FireLog - INFO - filtering and clustering 2025-5-18 AM, VIIRS, Central_America_Example
# 2025-09-04 05:13:54,124 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 73.44 ms
# 2025-09-04 05:13:54,197 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 73.51 ms
# 2025-09-04 05:13:54,217 - fireatlas.FireLog - INFO - func:read_region took: 1.80 sec
# 2025-09-04 05:13:54,218 - fireatlas.FireLog - INFO - filtering and clustering 2025-5-17 PM, VIIRS, Central_America_Example
# 2025-09-04 05:13:54,228 - fireatlas.FireLog - INFO - func:read_region took: 1.81 sec
# 2025-09-04 05:13:54,228 - fireatlas.FireLog - INFO - filtering and clustering 2025-5-15 PM, VIIRS, Central_America_Example
# 2025-09-04 05:13:54,276 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 78.10 ms
# 2025-09-04 05:13:54,280 - fireatlas.FireLog - INFO - func:read_region took: 1.86 sec
# 2025-09-04 05:13:54,281 - fireatlas.FireLog - INFO - filtering and clustering 2025-5-16 AM, VIIRS, Central_America_Example
# 2025-09-04 05:13:54,337 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 118.72 ms
# 2025-09-04 05:13:54,346 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 118.11 ms
# 2025-09-04 05:13:54,358 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 77.28 ms
# 2025-09-04 05:13:54,435 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 76.64 ms
# 2025-09-04 05:13:54,459 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 112.63 ms
# 2025-09-04 05:13:54,478 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 141.17 ms
# 2025-09-04 05:13:54,517 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 81.97 ms
# 2025-09-04 05:13:54,591 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 113.18 ms
# 2025-09-04 05:13:54,593 - fireatlas.FireLog - INFO - func:read_preprocessed_input took: 133.51 ms
# 2025-09-04 05:15:46,231 - fireatlas.FireLog - INFO - func:do_clustering took: 71.17 ms
# 2025-09-04 05:15:46,321 - fireatlas.FireLog - INFO - func:preprocess_region_t took: 1.90 min
# 2025-09-04 05:15:50,352 - fireatlas.FireLog - INFO - func:do_clustering took: 69.23 ms
# 2025-09-04 05:15:50,442 - fireatlas.FireLog - INFO - func:preprocess_region_t took: 1.97 min
# 2025-09-04 05:16:22,262 - fireatlas.FireLog - INFO - func:do_clustering took: 96.03 ms
# 2025-09-04 05:16:22,370 - fireatlas.FireLog - INFO - func:preprocess_region_t took: 2.50 min
# 2025-09-04 05:18:06,215 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('job_preprocess_region_t-c64b2ea16f30125881bc4432ccdd67aa')" coro=<Worker.execute() done, defined at /opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-09-04 05:18:06,215 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('job_preprocess_region_t-1ed1ecda2458d601487c80c3b1e081d4')" coro=<Worker.execute() done, defined at /opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-09-04 05:18:06,215 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('job_preprocess_region_t-c9897db144eb85669383b0931f4d2c41')" coro=<Worker.execute() done, defined at /opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-09-04 05:18:06,229 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36795' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'copy_from_local_to_s3-e812c96cb5d3e774e8c0ff59ad4c3e18', 'preprocess_daily_file-bfd321c99bd396c7e04e42b7b446975d', 'copy_from_local_to_s3-a68f0c1fb239572c334128822e246b45', 'preprocess_daily_file-b8132211f810acd9e770f98077f47473', 'copy_from_local_to_s3-4151ad3e074092aeb5bb10b5995b1cf7', 'copy_from_local_to_s3-97bffe6cb47ed332fd0eaa3e0d4404cc', 'copy_from_local_to_s3-73d11f17dfc907f3c9dd86256afe9175', 'copy_from_local_to_s3-cefb0303d087090cb0a834abbe7b6365', 'copy_from_local_to_s3-5593d8b76bf83009cca388dd5d08e288', 'copy_from_local_to_s3-eed96aee22361e12f0062eec17960038', 'copy_from_local_to_s3-52ff79e3356bb502fc4e69376f30ed68', 'copy_from_local_to_s3-ccfa31a9bf7d62756bef6b3a3a3fcf20', 'copy_from_local_to_s3-433390dc3e1886d563ebeb279bbd7406', 'copy_from_local_to_s3-c7f6f844685ef090cf1ad1b6179e8967', 'copy_from_local_to_s3-520827de634606f1af8455d177be0617', 'copy_from_local_to_s3-254f0b5571a1953a563ed0b7b5c494d5', 'copy_from_local_to_s3-06895e980c55497c74cf1be3d796704c', 'copy_from_local_to_s3-f3169673f7b42dbfe11fca5bb035ab61', 'copy_from_local_to_s3-578031be1077201018957fc27dcc172d', 'copy_from_local_to_s3-36ff317cdfaa902c5dcc15b9bcfeb125', 'copy_from_local_to_s3-a50cdfdb7075bf48322b4149b34daa2c', 'copy_from_local_to_s3-0c558656d278aa7875991cc0ae0054ec', 'job_preprocess_region_t-2
be7481b49f99a90aed', 'copy_from_local_to_s3-12368287910da243d319e87227df4530', 'copy_from_local_to_s3-3654b92eeabd25c6884fb6479d943ebb', 'copy_from_local_to_s3-c4daf28c0fa1634eaf693ec670b07899', 'copy_from_local_to_s3-c2c5180331ee8720e99648907b2cf1c3', 'preprocess_daily_file-6a4c1da9d765107809b5fbe85e539d50', 'copy_from_local_to_s3-4a022bec2883c3e4e20b9183e0ded771', 'copy_from_local_to_s3-7aa62a1efda5a61ff058b1941f065731', 'copy_from_local_to_s3-e2b075645f4fb1b96f510e1da2bd21be', 'copy_from_local_to_s3-da9e46483766e1e1f7bc8771d1f71007'} (stimulus_id='handle-worker-cleanup-1756988286.2417486')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Run(region=[region_name,bbox],tst=[2025,5,15,'PM'],ted=[2025,5,18,'AM'],copy_to_veda=False)
#
# File ~/fireatlas/fireatlas/utils.py:14, in timed.<locals>.wrap(*args, **kwargs)
#      11 t_start = time()
#      13 # run the function
# ---> 14 result = f(*args, **kwargs)
#      16 # capture the end time
#      17 t_end = time()
#
# File ~/fireatlas/fireatlas/FireRunDaskCoordinator.py:451, in Run(region, tst, ted, copy_to_veda)
#     446 region_and_t_futures = client.map(
#     447     partial(job_preprocess_region_t, region=region),
#     448     timesteps_needing_processing
#     449 )
#     450 # block until preprocessing is complete
# --> 451 client.gather(region_and_t_futures)
#     453 logger.info("------------- Done with preprocessing region + t -------------")
#     455 # run fire forward algorithm (which cannot be run in parallel)
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/client.py:2372, in Client.gather(self, futures, errors, direct, asynchronous)
#    2369     local_worker = None
#    2371 with shorten_traceback():
# -> 2372     return self.sync(
#    2373         self._gather,
#    2374         futures,
#    2375         errors=errors,
#    2376         direct=direct,
#    2377         local_worker=local_worker,
#    2378         asynchronous=asynchronous,
#    2379     )
#
# File /opt/conda/envs/pangeo/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /opt/conda/envs/pangeo/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2025-09-04 05:18:08,251 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/opt/conda/envs/pangeo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/pangeo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/envs/pangeo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/envs/pangeo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/pangeo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/envs/pangeo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/envs/pangeo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/pangeo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/envs/pangeo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/envs/pangeo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/envs/pangeo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-09-04 05:18:25,258 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-09-04 05:18:25,259 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-09-04 05:18:25,260 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing

# %%
# optionally display all files
# s3.glob(f's3://maap-ops-workspace/shared/zbecker/FEDSstaging/FEDSoutput-v3/{region_name}/**')

# %%
lf_files = s3.glob(f's3://maap-ops-workspace/shared/zbecker/FEDSstaging/FEDSoutput-v3/{region_name}/2025/CombinedLargefire/**/lf_perimeter.fgb')
lf_files
# Out:
# ['maap-ops-workspace/shared/zbecker/FEDSstaging/FEDSoutput-v3/Central_America_Example/2025/CombinedLargefire/20250602AM/lf_perimeter.fgb',
#  'maap-ops-workspace/shared/zbecker/FEDSstaging/FEDSoutput-v3/Central_America_Example/2025/CombinedLargefire/20250605AM/lf_perimeter.fgb']

# %%
# read in most recent lf_perimeter file: 
perimeters = gpd.read_file("s3://"+lf_files[-1])
