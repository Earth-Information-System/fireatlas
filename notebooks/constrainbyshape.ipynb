# %%
from fireatlas import FireRun, settings
import os

# %%
settings.LOCAL_PATH
# Out:
# 'd:\\pyFOFEM\\data'
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
firepath = os.path.join(settings.LOCAL_PATH, 'FEDSinput', 'perimeters', 'THOMAS_00003583.fgb')
FireRun.constrainByShape_Run(firepath)
# Out:
# 2024-11-20 12:02:47,602 - fireatlas.FireLog - INFO - Preprocessing has already occurred for this landcover file.
# 2024-11-20 12:02:47,605 - fireatlas.FireLog - INFO - func:preprocess_landcover took: 3.08 ms
# 2024-11-20 12:02:47,788 - fireatlas.FireLog - INFO - =============== Running: THOMAS_00003583 ===============
# 2024-11-20 12:02:47,789 - fireatlas.FireLog - INFO - Preprocessing has already occurred for this region.
# 2024-11-20 12:02:47,790 - fireatlas.FireLog - INFO - func:preprocess_region took: 0.96 ms
# 2024-11-20 12:02:47,817 - fireatlas.FireLog - INFO - func:read_region took: 22.09 ms
# 2024-11-20 12:02:47,819 - fireatlas.FireLog - INFO - Preprocessing has already occurred for this combination of timestep, sensor, and region.
# 2024-11-20 12:02:47,819 - fireatlas.FireLog - INFO - func:preprocess_region_t took: 0.95 ms
# 2024-11-20 12:02:47,821 - fireatlas.FireLog - INFO - Preprocessing has already occurred for this combination of timestep, sensor, and region.
# ...

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
